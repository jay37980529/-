# %% [markdown]
# # 第14組
# ## 2020電動機車販售與補助金關係圖

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
data3 = pd.read_csv('2020.csv')
data3
# Out:
#    discricts  amount  subsidy  Unnamed: 3
# 0        基隆市   317.0   4000.0         NaN
# 1        臺北市  2139.0   3000.0         NaN
# 2        新北市  4767.0   4000.0         NaN
# 3        宜蘭縣   346.0      0.0         NaN
# 4        桃園市  3036.0   6000.0         NaN
# 5        新竹市   585.0      0.0         NaN
# 6        新竹縣   629.0   5000.0         NaN
# 7        苗栗縣   290.0      0.0         NaN
# 8        臺中市  4577.0   3000.0         NaN
# 9        彰化縣   961.0      0.0         NaN
# 10       南投縣   358.0      0.0         NaN
# 11       雲林縣   602.0      0.0         NaN
# 12       嘉義市   532.0   8000.0         NaN
# 13       嘉義縣   256.0   3000.0         NaN
# 14       臺南市  3617.0   6000.0         NaN
# 15       高雄市  3817.0      0.0         NaN
# 16       屏東縣  1107.0      0.0         NaN
# 17       花蓮縣   504.0      0.0         NaN
# 18       臺東縣   359.0      0.0         NaN
# 19       澎湖縣    43.0      0.0         NaN
# 20       金門縣    41.0  24000.0         NaN
# ...

# %%
data3.drop(columns=['Unnamed: 3'], inplace = True)

# %%
data3.drop(22,axis=0,inplace=True)

# %%
data3
# Out:
#    discricts  amount  subsidy
# 0        基隆市   317.0   4000.0
# 1        臺北市  2139.0   3000.0
# 2        新北市  4767.0   4000.0
# 3        宜蘭縣   346.0      0.0
# 4        桃園市  3036.0   6000.0
# 5        新竹市   585.0      0.0
# 6        新竹縣   629.0   5000.0
# 7        苗栗縣   290.0      0.0
# 8        臺中市  4577.0   3000.0
# 9        彰化縣   961.0      0.0
# 10       南投縣   358.0      0.0
# 11       雲林縣   602.0      0.0
# 12       嘉義市   532.0   8000.0
# 13       嘉義縣   256.0   3000.0
# 14       臺南市  3617.0   6000.0
# 15       高雄市  3817.0      0.0
# 16       屏東縣  1107.0      0.0
# 17       花蓮縣   504.0      0.0
# 18       臺東縣   359.0      0.0
# 19       澎湖縣    43.0      0.0
# 20       金門縣    41.0  24000.0
# 21       連江縣     2.0      0.0

# %%
data3['Districts2'] = ""

# %%
data3
# Out:
#    discricts  amount  subsidy Districts2
# 0        基隆市   317.0   4000.0
# 1        臺北市  2139.0   3000.0
# 2        新北市  4767.0   4000.0
# 3        宜蘭縣   346.0      0.0
# 4        桃園市  3036.0   6000.0
# 5        新竹市   585.0      0.0
# 6        新竹縣   629.0   5000.0
# 7        苗栗縣   290.0      0.0
# 8        臺中市  4577.0   3000.0
# 9        彰化縣   961.0      0.0
# 10       南投縣   358.0      0.0
# 11       雲林縣   602.0      0.0
# 12       嘉義市   532.0   8000.0
# 13       嘉義縣   256.0   3000.0
# 14       臺南市  3617.0   6000.0
# 15       高雄市  3817.0      0.0
# 16       屏東縣  1107.0      0.0
# 17       花蓮縣   504.0      0.0
# 18       臺東縣   359.0      0.0
# 19       澎湖縣    43.0      0.0
# 20       金門縣    41.0  24000.0
# 21       連江縣     2.0      0.0

# %%
data3.rename(columns = {'discricts' : 'District'}, inplace = True)
data3
# Out:
#    District  amount  subsidy Districts2
# 0       基隆市   317.0   4000.0
# 1       臺北市  2139.0   3000.0
# 2       新北市  4767.0   4000.0
# 3       宜蘭縣   346.0      0.0
# 4       桃園市  3036.0   6000.0
# 5       新竹市   585.0      0.0
# 6       新竹縣   629.0   5000.0
# 7       苗栗縣   290.0      0.0
# 8       臺中市  4577.0   3000.0
# 9       彰化縣   961.0      0.0
# 10      南投縣   358.0      0.0
# 11      雲林縣   602.0      0.0
# 12      嘉義市   532.0   8000.0
# 13      嘉義縣   256.0   3000.0
# 14      臺南市  3617.0   6000.0
# 15      高雄市  3817.0      0.0
# 16      屏東縣  1107.0      0.0
# 17      花蓮縣   504.0      0.0
# 18      臺東縣   359.0      0.0
# 19      澎湖縣    43.0      0.0
# 20      金門縣    41.0  24000.0
# 21      連江縣     2.0      0.0

# %%
nep_districts = gpd.read_file(r'TWN_adm/TWN_adm2.shp')
nep_districts
# Out:
#     ID_0  ISO  NAME_0  ID_1          NAME_1  ID_2          NAME_2  \
# 0    225  TWN  Taiwan     1       Kaohsiung     1  Kaohsiung City
# 1    225  TWN  Taiwan     2  Pratas Islands     2            None
# 2    225  TWN  Taiwan     3          Taipei     3     Taipei City
# 3    225  TWN  Taiwan     4          Taiwan     4        Changhwa
# 4    225  TWN  Taiwan     4          Taiwan     5          Chiayi
# 5    225  TWN  Taiwan     4          Taiwan     6         Hsinchu
# 6    225  TWN  Taiwan     4          Taiwan     7         Hualien
# 7    225  TWN  Taiwan     4          Taiwan     8            Ilan
# 8    225  TWN  Taiwan     4          Taiwan     9       Kaohsiung
# 9    225  TWN  Taiwan     4          Taiwan    10    Keelung City
# 10   225  TWN  Taiwan     4          Taiwan    11          Miaoli
# 11   225  TWN  Taiwan     4          Taiwan    12          Nantou
# 12   225  TWN  Taiwan     4          Taiwan    13          Penghu
# ...

# %%
nep_districts = nep_districts[['NAME_2', 'geometry']]
nep_districts.rename(columns = {'NAME_2' : 'District'}, inplace = True)
# Out:
# C:\Users\jayvu\Anaconda3\lib\site-packages\pandas\core\frame.py:4223: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)

# %%
nep_districts
# Out:
#           District                                           geometry
# 0   Kaohsiung City  MULTIPOLYGON (((120.23904 22.75155, 120.23875 ...
# 1             None  POLYGON ((116.71722 20.70959, 116.71778 20.709...
# 2      Taipei City  POLYGON ((121.52582 24.95191, 121.45911 24.930...
# 3         Changhwa  MULTIPOLYGON (((120.46427 24.16347, 120.46403 ...
# 4           Chiayi  MULTIPOLYGON (((120.13403 23.37264, 120.13403 ...
# 5          Hsinchu  MULTIPOLYGON (((121.25690 24.36170, 121.22860 ...
# 6          Hualien  MULTIPOLYGON (((120.99192 23.47921, 121.06472 ...
# 7             Ilan  MULTIPOLYGON (((121.84292 24.47625, 121.84236 ...
# 8        Kaohsiung  MULTIPOLYGON (((120.33847 22.55153, 120.33847 ...
# 9     Keelung City  MULTIPOLYGON (((121.78680 25.19514, 121.78680 ...
# 10          Miaoli  POLYGON ((120.61208 24.42708, 120.61236 24.427...
# 11          Nantou  POLYGON ((120.66179 23.60818, 120.61855 23.632...
# ...

# %%
for index, row in nep_districts['District'].iteritems():
    if row in data3['District'].tolist():
        pass
    else:
        print('The district ', row , ' is NOT in the data3 list')
# Out:
# The district  Kaohsiung City  is NOT in the data3 list
# The district  None  is NOT in the data3 list
# The district  Taipei City  is NOT in the data3 list
# The district  Changhwa  is NOT in the data3 list
# The district  Chiayi  is NOT in the data3 list
# The district  Hsinchu  is NOT in the data3 list
# The district  Hualien  is NOT in the data3 list
# The district  Ilan  is NOT in the data3 list
# The district  Kaohsiung  is NOT in the data3 list
# The district  Keelung City  is NOT in the data3 list
# The district  Miaoli  is NOT in the data3 list
# The district  Nantou  is NOT in the data3 list
# The district  Penghu  is NOT in the data3 list
# The district  Pingtung  is NOT in the data3 list
# The district  Taichung City  is NOT in the data3 list
# The district  Taichung  is NOT in the data3 list
# The district  Tainan City  is NOT in the data3 list
# The district  Tainan  is NOT in the data3 list
# The district  Taipei  is NOT in the data3 list
# ...

# %%
nep_districts.replace('Changhwa', '彰化縣', inplace = True)
nep_districts.replace('Chiayi', '嘉義市', inplace = True)
nep_districts.replace('Hsinchu', '新竹市', inplace = True)
nep_districts.replace('Hualien', '花蓮縣', inplace = True)
nep_districts.replace('Ilan', '宜蘭縣', inplace = True)
nep_districts.replace('Kaohsiung', '高雄市', inplace = True)
nep_districts.replace('Kaohsiung City', '高雄市', inplace = True)
nep_districts.replace('Keelung City', '基隆市', inplace = True)
nep_districts.replace('Miaoli', '苗栗縣', inplace = True)
nep_districts.replace('Nantou', '南投縣', inplace = True)
nep_districts.replace('Penghu', '澎湖縣', inplace = True)
nep_districts.replace('Pingtung', '屏東縣', inplace = True)
nep_districts.replace('Taichung', '臺中市', inplace = True)
nep_districts.replace('Taichung City', '臺中市', inplace = True)
nep_districts.replace('Taipei City', '臺北市', inplace = True)
nep_districts.replace('Tainan', '臺南市', inplace = True)
nep_districts.replace('Tainan City', '臺南市', inplace = True)
nep_districts.replace('Taipei', '臺北市', inplace = True)
nep_districts.replace('Taitung', '臺東縣', inplace = True)
nep_districts.replace('Taoyuan', '桃園市', inplace = True)
nep_districts.replace('Yunlin', '雲林縣', inplace = True)
# Out:
# C:\Users\jayvu\Anaconda3\lib\site-packages\pandas\core\frame.py:4263: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
nep_districts
# Out:
#    District                                           geometry
# 0       高雄市  (POLYGON ((120.2390365600586 22.7515544891358,...
# 1      None  POLYGON ((116.7172241210938 20.70959472656256,...
# 2       臺北市  POLYGON ((121.5258178710939 24.95191001892101,...
# 3       彰化縣  (POLYGON ((120.4642715454102 24.1634731292724,...
# 4       嘉義市  (POLYGON ((120.1340255737306 23.37264060974132...
# 5       新竹市  (POLYGON ((121.2568969726563 24.3617000579834,...
# 6       花蓮縣  (POLYGON ((120.9919204711915 23.47921180725092...
# 7       宜蘭縣  (POLYGON ((121.8429183959961 24.47624969482428...
# 8       高雄市  (POLYGON ((120.3384704589845 22.55152702331554...
# 9       基隆市  (POLYGON ((121.7868041992188 25.19513893127447...
# 10      苗栗縣  POLYGON ((120.6120834350586 24.42708396911621,...
# 11      南投縣  POLYGON ((120.6617889404298 23.60818290710461,...
# 12      澎湖縣  (POLYGON ((119.6015243530273 23.78808593750006...
# 13      屏東縣  (POLYGON ((120.6965255737305 22.04069709777832...
# ...

# %%
nep_districts['area'] = nep_districts.area*10000
# Out:
# C:\Users\jayvu\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
nep_districts = nep_districts.merge(data3, on = 'District')

nep_districts
# Out:
#    District                                           geometry         area  \
# 0       高雄市  MULTIPOLYGON (((120.23904 22.75155, 120.23875 ...    60.171779
# 1       高雄市  MULTIPOLYGON (((120.33847 22.55153, 120.33847 ...  2658.084843
# 2       臺北市  POLYGON ((121.52582 24.95191, 121.45911 24.930...   237.923336
# 3       臺北市  MULTIPOLYGON (((122.07875 25.63431, 122.07875 ...  2044.269632
# 4       彰化縣  MULTIPOLYGON (((120.46427 24.16347, 120.46403 ...  1055.277694
# 5       嘉義市  MULTIPOLYGON (((120.13403 23.37264, 120.13403 ...  1524.890150
# 6       新竹市  MULTIPOLYGON (((121.25690 24.36170, 121.22860 ...  1557.450909
# 7       花蓮縣  MULTIPOLYGON (((120.99192 23.47921, 121.06472 ...  4157.147255
# 8       宜蘭縣  MULTIPOLYGON (((121.84292 24.47625, 121.84236 ...  2295.588529
# 9       基隆市  MULTIPOLYGON (((121.78680 25.19514, 121.78680 ...    70.597241
# 10      苗栗縣  POLYGON ((120.61208 24.42708, 120.61236 24.427...  1332.644296
# ...

# %%
for index, row in nep_districts.iterrows():
    if '[' and ']' in row['District']:
        start_index = row['District'].find('[')
        end_index = row['District'].find(']')
        nep_districts.loc[index, 'Districts2'] = nep_districts.loc[index]['District'][start_index+1: end_index]
        
    else:
        nep_districts.loc[index, 'Districts2'] = nep_districts.loc[index]['District']

# %%
nep_districts
# Out:
#    District                                           geometry         area  \
# 0       高雄市  MULTIPOLYGON (((120.23904 22.75155, 120.23875 ...    60.171779
# 1       高雄市  MULTIPOLYGON (((120.33847 22.55153, 120.33847 ...  2658.084843
# 2       臺北市  POLYGON ((121.52582 24.95191, 121.45911 24.930...   237.923336
# 3       臺北市  MULTIPOLYGON (((122.07875 25.63431, 122.07875 ...  2044.269632
# 4       彰化縣  MULTIPOLYGON (((120.46427 24.16347, 120.46403 ...  1055.277694
# 5       嘉義市  MULTIPOLYGON (((120.13403 23.37264, 120.13403 ...  1524.890150
# 6       新竹市  MULTIPOLYGON (((121.25690 24.36170, 121.22860 ...  1557.450909
# 7       花蓮縣  MULTIPOLYGON (((120.99192 23.47921, 121.06472 ...  4157.147255
# 8       宜蘭縣  MULTIPOLYGON (((121.84292 24.47625, 121.84236 ...  2295.588529
# 9       基隆市  MULTIPOLYGON (((121.78680 25.19514, 121.78680 ...    70.597241
# 10      苗栗縣  POLYGON ((120.61208 24.42708, 120.61236 24.427...  1332.644296
# ...

# %%
nep_districts['amo_den (amount/sq. km)'] = nep_districts['amount']/100000

# %% [markdown]
# # 縣市機車購買數關係圖

# %%
nep_districts.plot(column = 'amo_den (amount/sq. km)', cmap = 'Spectral', legend = True)

# %%
nep_districts['sub_den (subsidy/sq. km)'] = nep_districts['subsidy']/100000

# %% [markdown]
# # 縣市電動機車補助關係圖

# %%
nep_districts.plot(column = 'sub_den (subsidy/sq. km)', cmap = 'Spectral', legend = True)
